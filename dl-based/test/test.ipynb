# %%
import os
import sys

sys.path.append("/data/zhangyufeng/Rec/dl-based")

# %%
from models import PNN

# %%
pnn = PNN()
# Out:
# models.PNN.PNN

# %%
import torch

# %%
# 创建示例数据
vector = torch.tensor([[1], [2], [3]])
matrix = torch.tensor([[1, 2, 3, 1], [4, 5, 6, 1], [7, 8, 9, 1]])

vector, matrix
# Out:
# (tensor([[1],
#          [2],
#          [3]]),
#  tensor([[1, 2, 3, 1],
#          [4, 5, 6, 1],
#          [7, 8, 9, 1]]))

# %%
torch.outer(vector.reshape(-1), vector.reshape(-1))
# Out:
# tensor([[1, 2, 3],
#         [2, 4, 6],
#         [3, 6, 9]])

# %%
vector.reshape(-1, 1)
# Out:
# tensor([1, 2, 3])
